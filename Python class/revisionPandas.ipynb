# %%
import pandas as pd
from IPython.lib.pretty import Printable
from pandas.io.formats.format import return_docstring
from tornado.options import options

que = pd.read_csv("Questions.csv")
randomeQuestions = que.sample(1)
questions = list(dict(randomeQuestions)["Question"])
OptionsAs = list(dict(randomeQuestions)["Option A"])
OptionsBs = list(dict(randomeQuestions)["Option B"])
OptionsCs = list(dict(randomeQuestions)["Option C"])
OptionsDs = list(dict(randomeQuestions)["Option D"])
RightAnswers = list(dict(randomeQuestions)["Right Answer"])
import os
import pandas as pd

name = input("Enter your name: ").title()

# Check if user already attempted quiz
if os.path.exists("result.csv") and os.path.getsize("result.csv") > 0:

    results = pd.read_csv("result.csv")

    print(results)          # Check stored users
    print(results.columns)  # Check column names

    if "Name" in results.columns:
        if name.strip().lower() in results["Name"].astype(str).str.strip().str.lower().values:
            print(" You have already taken this quiz!")
            exit()
print("Welcome to Python Class Quiz, Let's start the quiz.")
score = 0
for i in range(len(questions)):
    print(f"\nQuestion {i+1}")
    print(questions[i])

    print("A.", OptionsAs[i])
    print("B.", OptionsBs[i])
    print("C.", OptionsCs[i])
    print("D.", OptionsDs[i])

    answer = input("Enter your answer (A/B/C/D): ").upper()
    if answer == RightAnswers[i]:
        print("Correct")
        score += 1
    else:
        print("Wrong")
        print("Correct Answer:", RightAnswers[i])
print(f"Your Name is: {name}")
print(f"Your Score is : {score}")
import os

result = pd.DataFrame({
    "Name": [name.strip()],
    "Score": [score]
})
file_exists = os.path.exists("result.csv") and os.path.getsize("result.csv") > 0

result.to_csv(
    "result.csv",
    mode="a",
    index=False,
    header=not file_exists
)

print("Result saved successfully!")
# Out:
#    Usman  0
# 0    Ali  0
# 1    Ali  1
# 2    Ali  1
# 3  Usman  0
# Index(['Usman', '0'], dtype='str')
# Welcome to Python Class Quiz, Let's start the quiz.
#
# Question 1
# How many sides does an octagon have?
# A. 6
# B. 7
# C. 8
# D. 9
# Wrong
# Correct Answer: C
# Your Name is: Usman
# Your Score is : 0
# Result saved successfully!

# %%
import pandas as pd
que = pd.read_csv("Questions.csv")
randomeQuestions = que.sample(1)
questions = list(dict(randomeQuestions)["Question"])
OptionsAs = list(dict(randomeQuestions)["Option A"])
OptionsBs = list(dict(randomeQuestions)["Option B"])
OptionsCs = list(dict(randomeQuestions)["Option C"])
OptionsDs = list(dict(randomeQuestions)["Option D"])
RightAnswers = list(dict(randomeQuestions)["Right Answer"])
name = input("Enter your name: ").title()
if "Name" in results.values:
    if name.strip().lower() in results["Name"].astype(str).str.strip().str.lower().values:
            print(" You have already taken this quiz!")
            exit()
print("Welcome to Python Class Quiz, Let's start the quiz.")
score = 0
for i in range(len(questions)):
    print(f"\nQuestion {i+1}")
    print(questions[i])

    print("A.", OptionsAs[i])
    print("B.", OptionsBs[i])
    print("C.", OptionsCs[i])
    print("D.", OptionsDs[i])

    answer = input("Enter your answer (A/B/C/D): ").upper()
    if answer == RightAnswers[i]:
        print("Correct")
        score += 1
    else:
        print("Wrong")
        print("Correct Answer:", RightAnswers[i])
print(f"Your Name is: {name}")
print(f"Your Score is : {score}")
import os

result = pd.DataFrame({
    "Name": [name.strip()],
    "Score": [score]
})
file_exists = os.path.exists("result.csv") and os.path.getsize("result.csv") > 0

result.to_csv(
    "result.csv",
    mode="a",
    index=False,
    header=not file_exists
)

print("Result saved successfully!")
# Out:
# Welcome to Python Class Quiz, Let's start the quiz.
#
# Question 1
# What is the primary language spoken in Brazil?
# A. Spanish
# B. English
# C. French
# D. Portuguese
# Wrong
# Correct Answer: D
# Your Name is: Usman
# Your Score is : 0
# Result saved successfully!

# %%
import pandas as pd
import os

# Read Questions
que = pd.read_csv("Questions.csv")
randomeQuestions = que.sample(2)

questions = list(randomeQuestions["Question"])
OptionsAs = list(randomeQuestions["Option A"])
OptionsBs = list(randomeQuestions["Option B"])
OptionsCs = list(randomeQuestions["Option C"])
OptionsDs = list(randomeQuestions["Option D"])
RightAnswers = list(randomeQuestions["Right Answer"])


# Take user name
name = input("Enter your name: ").title()

# Check previous result
if os.path.exists("result1.csv"):
    results = pd.read_csv("result1.csv")

    if name.strip().lower() in results["Name"]:
        print("You have already taken this quiz!")
    exit()

else:
    print("\nWelcome to Python Class Quiz, Let's start the quiz.")

score = 0

for i in range(len(questions)):
    print("===================//===============")
    print(f"\nQuestion {i+1}")
    print(questions[i])

    print("A.", OptionsAs[i])
    print("B.", OptionsBs[i])
    print("C.", OptionsCs[i])
    print("D.", OptionsDs[i])

    answer = input("Enter your answer (A/B/C/D): ").upper()

    if answer == RightAnswers[i]:
        print("Correct")
        score += 1
    else:
        print("Wrong")
        print("Correct Answer:", RightAnswers[i])

print("\nYour Name is:", name)
print("Your Score is:", score)


# Save Result
result1 = pd.DataFrame({
    "Name": [name],
    "Score": [score]
})


file_exists = os.path.exists("result1.csv")

result1.to_csv(
    "result1.csv",
    mode="a",
    index=False,
    header=not file_exists
)

print("Result saved successfully!")
# Out:
# ===================//===============
#
# Question 1
# How many primary colors are there?
# A. 2
# B. 3
# C. 4
# D. 5
# Wrong
# Correct Answer: B
# ===================//===============
#
# Question 2
# What is the capital of Canada?
# A. Toronto
# B. Vancouver
# C. Montreal
# D. Ottawa
# Wrong
# Correct Answer: D
#
# Your Name is: Usman
# Your Score is: 0
# Result saved successfully!

# %%
import os
import pandas as pd

if not os.path.exists("bank1.csv") or os.path.getsize("bank1.csv") == 0:
    df = pd.DataFrame(columns=["A/C # ", "name", "password", "A/C bal"])
else:
    df = pd.read_csv("bank1.csv")
bank={}
for i in range (len(df)):
    account = str(df["A/C # "][i])
    bank[account] = {
        "name": df["name"][i],
        "password": str(df["password"][i]),
        "bal":float(df["A/C bal"][i])
    }
while True:
    choice = int(input("1 to create new Account/ 2 to login / 3 to exit:"))
    if choice == 1:
        account = input("Enter account no. : ")
        if account in bank:
            print("Account already exists!")
        else:
            bank[account] = {}
            bank[account]["name"] = input("Enter account holder name: ")
            bank[account]["password"] = input("Enter account password: ")
            bank[account]["bal"] = float(input("Enter account opening bal: "))
            print("Account created successfully!")
    elif choice == 2:
        account = input("Enter account no. : ")
        password= input("Enter account password: ")
        if account in bank and password == bank[account]["password"]:
            print("login successfully!")
        while True:
            option = int(input("1 to balance inquiry, 2 to Deposit , 3 to withdraw, 4 to  logout: "))
            if option == 1:
                print(f"Your Name is {bank[account]['name']}")
                print(f"Your account balance is {bank[account]['bal']}")
            elif option == 2:
                amount = float(input("Enter amount to deposit: "))
                bank[account]["bal"] = bank[account]["bal"] + amount
                print("Your account balance is:", bank[account]["bal"])
            elif option == 3:
                amount = float(input("Enter amount to withdraw: "))
                if amount <=bank[account]["bal"]:
                    bank[account]["bal"] = bank[account]["bal"] - amount
                    print("Remaining balance is", bank[account]["bal"])
                else:
                    print("Insufficient balance")
            elif option == 4:
                print("Successfully logged out!")
                break
            else:
                print("Incorrect input")
        else:
            print("Incorrect password")
    elif choice == 3:
            accounts = []
            name = []
            password = []
            bal = []
            for account in bank:
                accounts.append(account)
                name.append(bank[account]["name"])
                password.append(bank[account]["password"])
                bal.append(bank[account]["bal"])
            df = pd.DataFrame({
            "A/C # ": accounts,
            "name": name,
            "password": password,
            "A/C bal": bal
    })
            df.to_csv("bank1.csv", index=False)
            print("Data Saved")
            break
    else:
        print("Invalid Choice")
# Out:
# Account created successfully!
# Remaining balance is 2700.0
# Your Name is Usman
# Your account balance is 2700.0
# Your Name is Usman
# Your account balance is 2700.0
# Successfully logged out!
# Data Saved

# %%
import pandas as pd
import os

FILE_NAME = "bank1.csv"


# -----------------------------
# Load Data
# -----------------------------
def load_data():
    if not os.path.exists(FILE_NAME) or os.path.getsize(FILE_NAME) == 0:
        df = pd.DataFrame(columns=["A/C #", "name", "password", "A/C bal"])
        df.to_csv(FILE_NAME, index=False)
        return {}

    df = pd.read_csv(FILE_NAME)

    bank = {}

    for _, row in df.iterrows():
        account = str(row["A/C #"])
        bank[account] = {
            "name": row["name"],
            "password": str(row["password"]),
            "bal": float(row["A/C bal"])
        }

    return bank


# -----------------------------
# Save Data
# -----------------------------
def save_data(bank):
    accounts = []
    names = []
    passwords = []
    balances = []

    for account, info in bank.items():
        accounts.append(account)
        names.append(info["name"])
        passwords.append(info["password"])
        balances.append(info["bal"])

    df = pd.DataFrame({
        "A/C #": accounts,
        "name": names,
        "password": passwords,
        "A/C bal": balances
    })

    df.to_csv(FILE_NAME, index=False)


# -----------------------------
# Create Account
# -----------------------------
def create_account(bank):
    account = input("Enter Account Number: ")

    if account in bank:
        print("❌ Account already exists.")
        return

    name = input("Enter Account Holder Name: ")
    password = input("Create Password: ")
    balance = float(input("Opening Balance: "))

    bank[account] = {
        "name": name,
        "password": password,
        "bal": balance
    }

    print("✅ Account Created Successfully.")


# -----------------------------
# Balance Inquiry
# -----------------------------
def balance_inquiry(bank, account):
    print("\n------ ACCOUNT DETAILS ------")
    print("Name    :", bank[account]["name"])
    print("Account :", account)
    print("Balance :", bank[account]["bal"])


# -----------------------------
# Deposit
# -----------------------------
def deposit(bank, account):
    amount = float(input("Enter Deposit Amount: "))

    if amount <= 0:
        print("Invalid amount.")
        return

    bank[account]["bal"] += amount

    print("Deposit Successful.")
    print("New Balance:", bank[account]["bal"])


# -----------------------------
# Withdraw
# -----------------------------
def withdraw(bank, account):
    amount = float(input("Enter Withdraw Amount: "))

    if amount <= 0:
        print("Invalid amount.")
        return

    if amount > bank[account]["bal"]:
        print("Insufficient Balance.")
    else:
        bank[account]["bal"] -= amount
        print("Withdrawal Successful.")
        print("Remaining Balance:", bank[account]["bal"])


# -----------------------------
# Login
# -----------------------------
def login(bank):
    account = input("Enter Account Number: ")
    password = input("Enter Password: ")

    if account not in bank:
        print("Account not found.")
        return

    if bank[account]["password"] != password:
        print("Incorrect Password.")
        return

    print(f"\nWelcome {bank[account]['name']}")

    while True:
        print("\n===== ACCOUNT MENU =====")
        print("1. Balance Inquiry")
        print("2. Deposit")
        print("3. Withdraw")
        print("4. Logout")

        choice = input("Enter Choice: ")

        if choice == "1":
            balance_inquiry(bank, account)

        elif choice == "2":
            deposit(bank, account)

        elif choice == "3":
            withdraw(bank, account)

        elif choice == "4":
            print("Logged Out Successfully.")
            break

        else:
            print("Invalid Choice.")


# -----------------------------
# Main Program
# -----------------------------
def main():
    bank = load_data()

    while True:
        print("\n========== BANK MANAGEMENT ==========")
        print("1. Create New Account")
        print("2. Login")
        print("3. Exit")

        choice = input("Enter Choice: ")

        if choice == "1":
            create_account(bank)

        elif choice == "2":
            login(bank)

        elif choice == "3":
            save_data(bank)
            print("Data Saved Successfully.")
            print("Thank You for Using Bank Management System.")
            break

        else:
            print("Invalid Choice.")


# -----------------------------
# Run Program
# -----------------------------
main()

# %%
import os
import pandas as pd

# Load existing data
if not os.path.exists("bank1.csv") or os.path.getsize("bank1.csv") == 0:
    df = pd.DataFrame(columns=["A/C # ", "name", "password", "A/C bal"])
else:
    df = pd.read_csv("bank1.csv")


# Store data in dictionary
bank = {}

for i in range(len(df)):
    account = str(df["A/C # "][i])
    bank[account] = {
        "name": df["name"][i],
        "password": str(df["password"][i]),
        "bal": float(df["A/C bal"][i])
    }


# Main Program
while True:

    choice = int(input("\n1. Create New Account\n2. Login\n3. Exit\nEnter Choice: "))


    # Create Account
    if choice == 1:

        account = input("Enter account number: ")

        if account in bank:
            print("Account already exists!")

        else:
            bank[account] = {}

            bank[account]["name"] = input("Enter account holder name: ")
            bank[account]["password"] = input("Enter account password: ")
            bank[account]["bal"] = float(input("Enter opening balance: "))

            print("Account created successfully!")


    # Login
    elif choice == 2:

        account = input("Enter account number: ")
        password = input("Enter password: ")


        if account in bank and password == bank[account]["password"]:

            print("\nLogin Successfully!")

            while True:

                option = int(input(
                    "\n1. Balance Inquiry"
                    "\n2. Deposit"
                    "\n3. Withdraw"
                    "\n4. Logout"
                    "\nEnter Choice: "
                ))


                # Balance
                if option == 1:

                    print("Account Holder:", bank[account]["name"])
                    print("Account Balance:", bank[account]["bal"])


                # Deposit
                elif option == 2:

                    amount = float(input("Enter deposit amount: "))

                    if amount > 0:
                        bank[account]["bal"] += amount
                        print("Updated Balance:", bank[account]["bal"])
                    else:
                        print("Invalid amount")


                # Withdraw
                elif option == 3:

                    amount = float(input("Enter withdrawal amount: "))

                    if amount <= 0:
                        print("Invalid amount")

                    elif amount <= bank[account]["bal"]:

                        bank[account]["bal"] -= amount
                        print("Remaining Balance:", bank[account]["bal"])

                    else:
                        print("Insufficient Balance")


                # Logout
                elif option == 4:

                    print("Logout Successfully!")
                    break


                else:
                    print("Invalid Choice")


        else:
            print("Incorrect Account Number or Password")


    # Exit and Save Data
    elif choice == 3:

        accounts = []
        names = []
        passwords = []
        balances = []


        for account in bank:

            accounts.append(account)
            names.append(bank[account]["name"])
            passwords.append(bank[account]["password"])
            balances.append(bank[account]["bal"])


        df = pd.DataFrame({
            "A/C # ": accounts,
            "name": names,
            "password": passwords,
            "A/C bal": balances
        })


        df.to_csv("bank1.csv", index=False)

        print("Data Saved Successfully!")
        print("Thank you for using Bank System")

        break


    else:
        print("Invalid Choice")

# %%
import pandas as pd

itemsDf = pd.read_excel("VendorProducts.xlsx",sheet_name="Items")
colectionsDf = pd.read_excel("VendorProducts.xlsx",sheet_name="Collections")

# %%
itemsDf["Price"] =itemsDf["Price"].astype(str)
itemsDf["Price"] = itemsDf["Price"].str.replace("د.ع","")
itemsDf["Price"] = itemsDf["Price"].str.replace(",","")
print(itemsDf["Price"])
# itemsDf.to_excel("VendorProducts_Cleaned.xlsx",sheet_name="item_clean", index=False)
# itemCleanDf= pd.read_excel("VendorProducts_Cleaned.xlsx",sheet_name="item_clean")
# itemCleanDf
# Out:
# 0         25000
# 1        300000
# 2         30000
# 3            00
# 4         15000
#           ...
# 24697     16500
# 24698     12000
# 24699     10500
# 24700     15000
# 24701     22500
# Name: Price, Length: 24702, dtype: str

# %%
print(colectionsDf)
# Out:
#        Item Id                             Item Name  \
# 0       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 1       390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
# 2       364804                          هايلايتر ستك
# 3       364804                          هايلايتر ستك
# 4       364793                            كونتور ستك
# ...        ...                                   ...
# 14481   332027       كونسيلر فوري مضاد للشيخوخة 6 مل
# 14482   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14483   316612  غسول الفم للثة الصحية بالنعناع النقي
# 14484   316610          غسول فم منعش بالنعناع الخفيف
# 14485   316610          غسول فم منعش بالنعناع الخفيف
#
#                           Secondary Item Name Color Code       Price  \
# 0            Bleu De Chanel L'Exclusif Parfum        NaN  420,000د.ع
# 1            Bleu De Chanel L'Exclusif Parfum        NaN  300,000د.ع
# 2                              The Glow Stick    #F3D5C6   19,750د.ع
# ...

# %%
colectionsDf["Price"] =colectionsDf["Price"].astype(str)
colectionsDf["Price"] = colectionsDf["Price"].str.replace("د.ع","")
colectionsDf["Price"] = colectionsDf["Price"].str.replace(",","")
print(colectionsDf["Price"])
# Out:
# 0        420000
# 1        300000
# 2         19750
# 3         19750
# 4         19750
#           ...
# 14481     17250
# 14482     17000
# 14483      6500
# 14484     17000
# 14485      6500
# Name: Price, Length: 14486, dtype: str

# %%
colectionsDf["Item Name"]=colectionsDf["Item Name"].astype(str)+colectionsDf["Color"].astype(str)
colectionsDf["Secondary Item Name"]=colectionsDf["Secondary Color"].astype(str)+colectionsDf["Secondary Color"].astype(str)

# %%
itemsDf=itemsDf.drop(columns=["Picture","Code","Barcode"])

# %%
itemsDf.head(2)
# Out:
#        Id                                  Name  \
# 0  390188            زيت الشفاه بليجر 001، 5 مل
# 1  390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد
#
#                      Secondary Name   Price  \
# 0        Pleasure Lip Oil 001, 5 ml   25000
# 1  Bleu De Chanel L'Exclusif Parfum  300000
#
#                                          Description  \
# 0  زيت مغذي للشفاه, يُعزز لمعان الشفاه بتأثير بصر...
# 1  عطر أروماتك إنيق للرجال.\nمكونات العطر: العنبر...
#
#                                Secondary Description  \
# 0  Nourishing lip oil that enhances lip shine wit...
# 1  An elegant aromatic fragrance for men.\nFragra...
#
#                                      Sub Description  \
# 0  |بوبا ميلانو|Pupa Milano|Lip Oil|زيت الشفاه|زي...
# 1  |شانيل|Chanel|العطور|Perfumes|عطر للرجال|عطر ر...
#
#   Secondary Sub Description  \
# 0                       NaN
# 1                       NaN
#
#                                                 Menu        Brand  \
# ...

# %%
colectionsDf.head(2)
# Out:
#        Id                                        Name Secondary Item Name  \
# 0  390187  عطر بلو دي شانيل لي اكسكلوسيف الجديد100 مل        100 ml100 ml
# 1  390187   عطر بلو دي شانيل لي اكسكلوسيف الجديد50 مل          50 ml50 ml
#
#   Color Code   Price        Barcode     Code   Color Secondary Color  Size  \
# 0        NaN  420000  3145891072204  82528.0  100 مل          100 ml   NaN
# 1        NaN  300000  3145891072105  82755.0   50 مل           50 ml   NaN
#
#   Unit Level  Is Active                                            Picture
# 0     Level1       True  https://www.storeakmedia.com/storeak-erp/Store...
# 1     Level1       True  https://www.storeakmedia.com/storeak-erp/Store...

# %%
colectionsDf.rename(columns={"Item Id":"Id","Item Name":"Name"},inplace=True)
