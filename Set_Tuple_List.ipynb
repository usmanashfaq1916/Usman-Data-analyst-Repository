# %%
li  =[1,2,"Usman",2,"Ashfaq"]
for i in li:
    if type(i) is str:
        print(i)
    else:
        pass
# Out:
# Usman
# Ashfaq

# %%
li.append("7")
print(li)
# Out:
# [1, 2, 'Usman', 2, 'Ashfaq', '2', '2', '7']

# %%
li.insert(2,9)
print(li)
# Out:
# [1, 2, 9, 'Usman', 2, 'Ashfaq', '2', '2', '7', 2, 2]

# %%
li.pop()
print(li)
# Out:
# [1, 2, 9, 'Usman', 2, 'Ashfaq', '2', '2', '7']
